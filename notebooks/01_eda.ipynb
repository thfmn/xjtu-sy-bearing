# %%
from google.cloud import bigquery
client = bigquery.Client(
    project='xjtu-bearing-failure',
    location='asia-southeast3'
)

# %% [markdown]
# ```python
# Client(
#     project=object,
#     credentials=None,
#     _http=None,
#     client_info=None,
#     client_options=None,
#     use_auth_w_custom_endpoint=True,
#     extra_headers={},
#     *,
#     api_key=None
# )
# ```

# %%
# Query only ONE file to save costs/memory
query = """
    SELECT *
    FROM `my_bearing_dataset.raw_signals`
    WHERE condition = '35Hz12kN'
      AND bearing_id = 'Bearing1_1'
    LIMIT 10000 -- Sample first 10k rows for quick check
"""
df = client.query(query).to_dataframe()
# Out:
# ---------------------------------------------------------------------------
# NotFound                                  Traceback (most recent call last)
# Cell In[7], line 9
#       1 # Query only ONE file to save costs/memory
#       2 query = """
#       3     SELECT *
#       4     FROM `my_bearing_dataset.raw_signals`
#    (...)      7     LIMIT 10000 -- Sample first 10k rows for quick check
#       8 """
# ----> 9 df = client.query(query).to_dataframe()
#
# File ~/Projects/Work/xjtu-sy-bearing/.venv/lib/python3.11/site-packages/google/cloud/bigquery/job/query.py:2159, in QueryJob.to_dataframe(self, bqstorage_client, dtypes, progress_bar_type, create_bqstorage_client, max_results, geography_as_object, bool_dtype, int_dtype, float_dtype, string_dtype, date_dtype, datetime_dtype, time_dtype, timestamp_dtype, range_date_dtype, range_datetime_dtype, range_timestamp_dtype)
#    1929 def to_dataframe(
#    1930     self,
# ...
